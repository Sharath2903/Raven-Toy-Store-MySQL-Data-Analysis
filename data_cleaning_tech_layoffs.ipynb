# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1dc1e806-f354-437d-9b10-a2071c8dbaee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1dc1e806-f354-437d-9b10-a2071c8dbaee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
tech_layoffs = pd.read_csv('tech_layoffs.csv')
tech_layoffs_location_new = pd.read_csv('tech_layoffs_location.csv')
tech_layoffs_Q2_2024 = pd.read_csv('tech_layoffs_Q2_2024.csv')
tech_layoffs_til_Q1_2024 = pd.read_csv('tech_layoffs_til_Q1_2024.csv')

# %%
print(tech_layoffs_location_new.columns)
# Out:
# Index(['location_HQ;Region;State;Country;latitude;longitude;;'], dtype='object')

# %%
tech_layoffs_location_new = pd.read_csv('tech_layoffs_location.csv', sep=';', engine='python')
print(tech_layoffs_location_new.columns)
# Out:
# Index(['location_HQ', 'Region', 'State', 'Country', 'latitude', 'longitude',
#        'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
tech_layoffs_location_new.head()
# Out:
#     location_HQ                  Region       State      Country     latitude  \
# 0      Adelaide                     NaN         NaN    Australia  -34,9281805
# 1  Agoura Hills                     NaN  California          USA     34,14791
# 2     Ahmedabad                     NaN         NaN        India   23,0216238
# 3       Alameda  San Francisco Bay Area  California          USA   37,6090291
# 4     Amsterdam                     NaN         NaN  Netherlands   52,3730796
#
#       longitude  Unnamed: 6  Unnamed: 7
# 0   138,5999312         NaN         NaN
# 1  -118,7657042         NaN         NaN
# 2    72,5797068         NaN         NaN
# 3   -121,899142         NaN         NaN
# 4     4,8924534         NaN         NaN

# %%
tech_layoffs_location_new = tech_layoffs_location_new.drop(columns = ['Unnamed: 6', 'Unnamed: 7'], errors='ignore')
tech_layoffs_location_new.head()
# Out:
#     location_HQ      Country     latitude     longitude
# 0      Adelaide    Australia  -34,9281805   138,5999312
# 1  Agoura Hills          USA     34,14791  -118,7657042
# 2     Ahmedabad        India   23,0216238    72,5797068
# 3       Alameda          USA   37,6090291   -121,899142
# 4     Amsterdam  Netherlands   52,3730796     4,8924534

# %%
print(tech_layoffs_location_new.Region.isnull().sum())
print(tech_layoffs_location_new.State.isnull().sum())
print(tech_layoffs_location_new.Country.isnull().sum())
print(tech_layoffs_location_new.location_HQ.isnull().sum())
# Out:
# 167
# 161
# 0
# 0

# %%
#dropping columns as they won't be necessary for the visualization
tech_layoffs_location_new = tech_layoffs_location_new.drop(columns = ['Region', 'State'])

# %%
tech_layoffs_location_new.head()
# Out:
#     location_HQ      Country     latitude     longitude
# 0      Adelaide    Australia  -34,9281805   138,5999312
# 1  Agoura Hills          USA     34,14791  -118,7657042
# 2     Ahmedabad        India   23,0216238    72,5797068
# 3       Alameda          USA   37,6090291   -121,899142
# 4     Amsterdam  Netherlands   52,3730796     4,8924534

# %%
tech_layoffs_location_new.to_csv('tech_layoffs_location_new.csv', index=False)
files.download('tech_layoffs_location_new.csv')
# Out:
#   File "<ipython-input-72-9908ea28859d>", line 2
#     tech_layoffs_location.to_csv('tech_layoffs_location_new.csv', index=False)
#     ^
# IndentationError: unexpected indent
